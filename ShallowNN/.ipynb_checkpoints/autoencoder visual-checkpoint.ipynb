# %%
import numpy as np
from autoencoder import Autoencoder
from sklearn import datasets
import matplotlib.pyplot as plt

P=Autoencoder(4,2)
# Out:
# heheh2

# %%
C=4 # Classes
X, Y = datasets.make_classification(
    n_features=C,
    n_classes=C,
    n_samples=100,
    n_redundant=0,
    n_clusters_per_class=1
)

"""Y_=[]
for i in range(len(X)):
    vec=np.zeros((C))
    vec[Y[i]]=1
    Y_+=[vec]
    """
# Out:
#   File "<ipython-input-8-4f0907d45901>", line 15
#     */
#      ^
# SyntaxError: invalid syntax

# %%
P.Train(X,np.array(Y_),200) # Train
# Out:
# 0.780807890742282
# 0.20327202592989793
# 0.17721888193794658
# 0.15565154119896332
# 0.15513326698951485
# 0.1550804044190187
# 0.15505610633655678
# 0.15503514496865706
# 0.15501423965289685
# 0.1549933754434876
# 0.15497283204838153
# 0.15495277990956333
# 0.15493329360608007
# 0.1549143973285544
# 0.15489609251520958
# 0.15487837118390593
# 0.15486122179779682
# 0.15484463170614837
# 0.1548285881080951
# 0.1548130784044333

# %%
plt.scatter(X[:,0],X[:,1],c=Y ) # Print points (only 2 coordenates) there are

# %%
X_r=P.Encode(X)
plt.scatter(X_r[0],X_r[1],c=Y)
